# %% [markdown]
# ## Automated Deep Ensemble with Uncertainty Quantification
#
# ## Imports and GPU Detection <a class="anchor" id="imports-and-gpu-detection"></a>
#
# <div class="alert alert-warning">
#
# <b>Warning</b>
#
# By design asyncio does not allow nested event loops. Jupyter is using Tornado which already starts an event loop. Therefore the following patch is required to run this tutorial.
#
# </div>

# %% [markdown]
# ## Installation from Develop Branch (fixed commit)
#
# ```console
# git clone -b develop git@github.com:deephyper/deephyper.git
# cd deephyper/
# git checkout fc08b61efa0222945622ce661131bde4362e5ffe
# pip install -e ".[default]"
# ```

# %%
#git clone -b develop git@github.com:deephyper/deephyper.git
#cd deephyper/
#git checkout fc08b61efa0222945622ce661131bde4362e5ffe
#pip install -e ".[default]"

# %%
#!pip install nest_asyncio

import nest_asyncio
nest_asyncio.apply()

# %%
import json
import os
import pathlib
import shutil

# !export TF_CPP_MIN_LOG_LEVEL=3
# !export TF_XLA_FLAGS=--tf_xla_enable_xla_devices

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tqdm import tqdm

# %% [markdown]
# <div class="alert alert-info">
#
# <b>Note</b>
#
# The `TF_CPP_MIN_LOG_LEVEL` can be used to avoid the logging of Tensorflow *DEBUG*, *INFO* and *WARNING* statements.
#
# </div>
#
# <div class="alert alert-info">
#
# <b>Note</b>
#
# The following can be used to detect if **GPU** devices are available on the current host.
#
# </div>

# %%
available_gpus = tf.config.list_physical_devices("GPU")
n_gpus = len(available_gpus)
if n_gpus > 1:
    n_gpus -= 1
is_gpu_available = n_gpus > 0

if is_gpu_available:
    print(f"{n_gpus} GPU{'s are' if n_gpus > 1 else ' is'} available.")
else:
    print("No GPU available")
# Out:
# No GPU available

# %%
dataset = np.load('../training-data/all_data.npy')

# %%
dataset.shape
# Out:
# (189, 1225)

# %%
dataset[:,0]
# Out:
# array([-2319.6447141 , -2319.40607004, -2319.63399504, -2319.63399504,
#        -2319.56461213, -2319.58957939, -2319.66081293, -2319.61458265,
#        -2319.61633854, -2319.47668683, -2319.58791233, -2319.59805758,
#        -2319.57444436, -2319.03627754, -2319.54345216, -2319.45546986,
#        -2319.15441285, -2319.10845954, -2318.73146826, -2319.10443649,
#        -2319.07291553, -2318.34131056, -2318.54845714, -2319.10674703,
#        -2319.02118615, -2319.21587163, -2319.11193483, -2319.03937137,
#        -2319.0838334 , -2318.60375171, -2318.9919471 , -2319.1995488 ,
#        -2318.72427134, -2319.18583175, -2319.08315693, -2318.98424475,
#        -2318.62254706, -2319.27037827, -2318.72756577, -2319.26833524,
#        -2318.88818962, -2319.15022144, -2319.11657124, -2318.60093464,
#        -2319.26246818, -2318.61643112, -2319.10328198, -2319.14255954,
#        -2319.13262361, -2318.9501868 , -2319.03255198, -2319.03994016,
#        -2319.18815906, -2319.1302584 , -2319.14716248, -2319.17404103,
#        -2319.03182918, -2319.31575658, -2318.75591382, -2319.2430629 ,
#        -2319.18585262, -2319.12021643, -2319.09671921, -2319.14928416,
#        -2319.05273834, -2318.94709204, -2319.01529113, -2318.44564174,
#        -2319.11814054, -2318.5167599 , -2319.21309809, -2319.18434888,
#        -2318.81048203, -2318.80658111, -2319.13724769, -2318.91251067,
#        -2319.21103736, -2319.08997373, -2319.00283155, -2319.00283155,
#        -2319.25903728, -2317.63191   , -2319.11014724, -2315.8076628 ,
#        -2318.2692164 , -2318.99719261, -2318.68549214, -2319.22818511,
#        -2318.75024211, -2319.08205851, -2318.57654352, -2319.00619175,
#        -2318.75196881, -2318.65014571, -2319.08733498, -2310.65847278,
#        -2310.65847278, -2310.54245117, -2310.43283901, -2310.38695458,
#        -2310.31828712, -2310.16642425, -2310.27915137, -2310.16780558,
#        -2310.30265604, -2310.34276418, -2310.50510189, -2310.50181618,
#        -2310.51775225, -2310.53313992, -2310.48609938, -2310.6049847 ,
#        -2310.70636278, -2310.60948881, -2310.52900933, -2310.57507717,
#        -2310.18021192, -2310.33167004, -2310.34729364, -2310.45982532,
#        -2310.60033109, -2310.4520668 , -2310.45982011, -2310.46355728,
#        -2310.44040785, -2310.33556695, -2310.35383857, -2310.46261774,
#        -2310.32262823, -2310.48853382, -2310.42764655, -2310.44518132,
#        -2310.43519575, -2310.33292576, -2310.44691734, -2310.34321535,
#        -2310.33628426, -2310.45394794, -2310.34346177, -2312.61252151,
#        -2313.54582628, -2313.5092972 , -2313.53801566, -2313.58485611,
#        -2313.57262625, -2313.43266526, -2313.31152776, -2313.17540964,
#        -2313.16388782, -2313.0474159 , -2312.93936039, -2313.02266438,
#        -2313.00693984, -2313.03273116, -2313.11493945, -2313.02917129,
#        -2312.9726736 , -2313.04768746, -2313.02569688, -2310.95886171,
#        -2313.05201216, -2313.03046455, -2313.0386907 , -2313.00145819,
#        -2312.42777179, -2312.9301192 , -2312.91139896, -2312.94779588,
#        -2312.94021133, -2312.77585643, -2313.04891733, -2313.04891733,
#        -2312.39780151, -2312.31066245, -2312.33209769, -2313.07975093,
#        -2312.23057259, -2313.07203413, -2313.25869181, -2312.56004281,
#        -2312.77976486, -2312.92222156, -2313.21545936, -2312.55386471,
#        -2312.62043989, -2313.16129041, -2313.16150517, -2312.95592416,
#        -2313.10175549])

# %%
print(min(dataset[:,0]))
print(max(dataset[:,0]))
# Out:
# -2319.66081293
# -2310.16642425

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
preprocessor_input = Pipeline([('stdscaler', StandardScaler()), ('minmax', MinMaxScaler(feature_range=(0, 1)))])
preprocessor_input.fit(dataset[:,1:])
preprocessor_output = Pipeline([('stdscaler', StandardScaler()), ('minmax', MinMaxScaler(feature_range=(0, 1)))])
preprocessor_output.fit(dataset[:,0].reshape(-1, 1))
X = preprocessor_input.transform(dataset[:,1:])
Y = preprocessor_output.transform(dataset[:,0].reshape(-1, 1))
print(X.shape)
print(Y.shape)
print(Y)
Y_train = Y
# Out:
# (189, 1224)
# (189, 1)
# [[0.00169562]
#  [0.02683089]
#  [0.0028246 ]
#  [0.0028246 ]
#  [0.01013238]
#  [0.0075027 ]
#  [0.        ]
#  [0.00486922]
#  [0.00468428]
#  [0.01939315]
#  [0.00767828]
#  [0.00660973]
#  [0.0090968 ]
#  [0.06577942]
#  [0.01236107]
#  [0.02162783]
#  [0.05333678]
#  [0.05817683]
#  [0.09788357]
#  [0.05860055]
#  [0.06192051]
#  [0.13897708]
#  [0.11715929]
#  [0.0583572 ]
#  [0.06736893]
#  [0.04686361]
#  [0.05781079]
#  [0.06545356]
#  [0.06077058]
#  [0.11133536]
#  [0.07044854]
#  [0.04858282]
#  [0.09864159]
#  [0.05002757]
#  [0.06084183]
#  [0.07125979]
#  [0.10935574]
#  [0.04112267]
#  [0.0982946 ]
#  [0.04133786]
#  [0.08137684]
#  [0.05377824]
#  [0.05732246]
#  [0.11163207]
#  [0.04195581]
#  [0.1099999 ]
#  [0.05872215]
#  [0.05458523]
#  [0.05563174]
#  [0.07484696]
#  [0.06617182]
#  [0.06539365]
#  [0.04978244]
#  [0.05588085]
#  [0.05410042]
#  [0.05126943]
#  [0.06624795]
#  [0.03634319]
#  [0.09530883]
#  [0.04399968]
#  [0.05002537]
#  [0.05693853]
#  [0.05941338]
#  [0.05387696]
#  [0.06404568]
#  [0.07517292]
#  [0.06798982]
#  [0.12798836]
#  [0.05715717]
#  [0.12049781]
#  [0.04715573]
#  [0.05018375]
#  [0.08956142]
#  [0.08997228]
#  [0.0551447 ]
#  [0.07881521]
#  [0.04737278]
#  [0.06012385]
#  [0.06930213]
#  [0.06930213]
#  [0.04231717]
#  [0.21369495]
#  [0.05799907]
#  [0.40583446]
#  [0.14657042]
#  [0.06989606]
#  [0.10272602]
#  [0.04556669]
#  [0.09590621]
#  [0.06095752]
#  [0.11420108]
#  [0.06894822]
#  [0.09572434]
#  [0.1064489 ]
#  [0.06040178]
#  [0.94817481]
#  [0.94817481]
#  [0.96039483]
#  [0.97193977]
#  [0.97677256]
#  [0.98400499]
#  [1.        ]
#  [0.98812697]
#  [0.99985451]
#  [0.98565134]
#  [0.98142693]
#  [0.96432865]
#  [0.96467472]
#  [0.96299625]
#  [0.96137554]
#  [0.9663301 ]
#  [0.95380846]
#  [0.94313077]
#  [0.95333406]
#  [0.96181059]
#  [0.95695848]
#  [0.99854781]
#  [0.98259543]
#  [0.98094986]
#  [0.96909742]
#  [0.9542986 ]
#  [0.96991459]
#  [0.96909797]
#  [0.96870435]
#  [0.97114258]
#  [0.98218498]
#  [0.98026052]
#  [0.96880331]
#  [0.98354776]
#  [0.96607369]
#  [0.97248666]
#  [0.97063981]
#  [0.97169154]
#  [0.98246317]
#  [0.97045696]
#  [0.98137941]
#  [0.98210943]
#  [0.96971646]
#  [0.98135346]
#  [0.7423639 ]
#  [0.64406323]
#  [0.64791067]
#  [0.64488589]
#  [0.6399524 ]
#  [0.64124051]
#  [0.65598196]
#  [0.66874081]
#  [0.6830775 ]
#  [0.68429104]
#  [0.69655849]
#  [0.70793948]
#  [0.69916545]
#  [0.70082164]
#  [0.69810516]
#  [0.68944655]
#  [0.69848011]
#  [0.70443075]
#  [0.69652989]
#  [0.69884605]
#  [0.91653623]
#  [0.69607439]
#  [0.6983439 ]
#  [0.69747747]
#  [0.701399  ]
#  [0.76182273]
#  [0.70891281]
#  [0.71088452]
#  [0.707051  ]
#  [0.70784985]
#  [0.72516059]
#  [0.69640035]
#  [0.69640035]
#  [0.76497936]
#  [0.77415732]
#  [0.77189964]
#  [0.69315279]
#  [0.78259281]
#  [0.69396556]
#  [0.67430578]
#  [0.74789124]
#  [0.72474893]
#  [0.70974463]
#  [0.67885925]
#  [0.74854195]
#  [0.74152989]
#  [0.68456461]
#  [0.68454199]
#  [0.70619489]
#  [0.69083515]]

# %%
dataset_test1 = np.load('../poscar_data/npy_data/feature_vectors_01.npy')
dataset_test2 = np.load('../poscar_data/npy_data/feature_vectors_02.npy')
dataset_test3 = np.load('../poscar_data/npy_data/feature_vectors_03.npy')
dataset_test4 = np.load('../poscar_data/npy_data/feature_vectors_04.npy')
dataset_test5 = np.load('../poscar_data/npy_data/feature_vectors_05.npy')

# %%
dataset_test = np.concatenate((dataset_test1,dataset_test2,dataset_test3,dataset_test4,dataset_test5), axis=0)

# %%
X_test = preprocessor_input.transform(dataset_test)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=100)
X_PCA = pca.fit(X)
print(pca.explained_variance_ratio_)
# Out:
# [8.84273750e-01 5.03982778e-02 3.36601537e-02 1.05068437e-02
#  7.78598044e-03 4.64567136e-03 2.74585984e-03 1.32655891e-03
#  1.04568513e-03 9.30753846e-04 6.61044046e-04 5.36579400e-04
#  3.48020759e-04 2.12472745e-04 1.61378258e-04 1.29472889e-04
#  1.00020986e-04 8.43440568e-05 6.22524915e-05 5.32187743e-05
#  4.69372641e-05 3.67146033e-05 3.44151052e-05 2.80821735e-05
#  2.48786982e-05 2.19230142e-05 2.05195034e-05 1.65556806e-05
#  1.51838408e-05 1.12382480e-05 8.19446322e-06 7.31452655e-06
#  6.63341620e-06 5.44359515e-06 4.62657897e-06 4.48309464e-06
#  4.10062999e-06 3.68380083e-06 3.29107398e-06 2.93257679e-06
#  2.68427070e-06 2.13736921e-06 2.11029724e-06 1.81509553e-06
#  1.75924431e-06 1.53805393e-06 1.09879270e-06 1.07501441e-06
#  1.00159635e-06 8.52128263e-07 7.69171656e-07 6.72572322e-07
#  6.48467397e-07 5.55689717e-07 5.11801963e-07 4.71136798e-07
#  4.18613962e-07 3.69976942e-07 3.61050477e-07 3.09213632e-07
#  2.82106965e-07 2.54534571e-07 2.39766754e-07 2.13374032e-07
#  2.00624070e-07 1.82002214e-07 1.63093224e-07 1.46334342e-07
#  1.31326114e-07 1.19813812e-07 1.05189696e-07 9.61142169e-08
#  9.39063829e-08 8.32155370e-08 7.47429328e-08 6.93272660e-08
#  6.56962332e-08 5.84659996e-08 5.66420258e-08 5.31063718e-08
#  4.94033103e-08 4.55894669e-08 4.30040637e-08 3.77133592e-08
#  3.49551846e-08 3.27092391e-08 3.18283870e-08 2.76042640e-08
#  2.59581033e-08 2.37232162e-08 2.24495360e-08 2.00909727e-08
#  1.82554754e-08 1.81043396e-08 1.64081303e-08 1.60440645e-08
#  1.44170571e-08 1.24258954e-08 1.17292368e-08 1.11713149e-08]

# %%
plt.figure(figsize=(8,4))
plt.plot(np.cumsum(pca.explained_variance_ratio_),linewidth=5)
plt.xlabel('Number of PCA components', fontsize=15)
plt.ylabel('Cumulative explained variance',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.tight_layout()
plt.savefig('train-pca.png')

# %%
X_train_PCA = pca.transform(X)
X_test_PCA = pca.transform(X_test)

# %%
flags = [0] * X_test_PCA.shape[0] + [1] * X_train_PCA.shape[0]

# %%
print(X_train_PCA.shape)
print(X_test_PCA.shape)
# Out:
# (189, 100)
# (50000, 100)

# %%
all_X_data = np.concatenate((X_test_PCA,X_train_PCA), axis=0)

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2).fit_transform(all_X_data)
X_embedded.shape
# Out:
# (50189, 2)

# %%
if 0:
    import matplotlib.pyplot as plt
    plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c=flags, cmap='rainbow')
    plt.colorbar()
    plt.show()

# %% [markdown]
# ## Start Ray
#
# We launch the Ray run-time depending on the detected local ressources. If GPU(s) is(are) detected then 1 worker is started for each GPU. If not, then only 1 worker is started. You can start more workers by setting `num_cpus=1` to a value greater than 1.
#
# <div class="alert alert-warning">
#
# <b>Warning</b>
#
# In the case of GPUs it is important to follow this scheme to avoid multiple processes (Ray workers vs current process) to lock the same GPU.
#
# </div>

# %%
import ray

if not(ray.is_initialized()):
    if is_gpu_available:
        ray.init(num_cpus=n_gpus, num_gpus=n_gpus, log_to_driver=False)            
    else:
        ray.init(num_cpus=4, log_to_driver=False)
# Out:
# 2023-10-24 18:56:53,100	INFO worker.py:1633 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265

# %%
def load_data_train_test(random_state=42):
    X = X_train_PCA #np.load('X.npy')
    Y = Y_train #np.load('Y.npy')

    return (X, Y), (X, Y)

# %%
from sklearn.model_selection import train_test_split

def load_data_train_valid(verbose=0, random_state=42):

    (x, y), _ = load_data_train_test(random_state=random_state)

    train_X, valid_X, train_y, valid_y = train_test_split(
        x, y, test_size=0.33, random_state=random_state
    )

    if verbose:
        print(f'train_X shape: {np.shape(train_X)}')
        print(f'train_y shape: {np.shape(train_y)}')
        print(f'valid_X shape: {np.shape(valid_X)}')
        print(f'valid_y shape: {np.shape(valid_y)}')
    return (train_X, train_y), (valid_X, valid_y)


(x, y), (vx, vy) = load_data_train_valid(verbose=1)
_, (tx , ty) = load_data_train_test()
# Out:
# train_X shape: (126, 100)
# train_y shape: (126, 1)
# valid_X shape: (63, 100)
# valid_y shape: (63, 1)

# %%
s_x = x
s_y = y
s_vx = vx
s_vy = vy

# %%
s_x.shape
# Out:
# (126, 100)

# %% [markdown]
# <div class="alert alert-info">
#
# <b>Note</b>
#
# When it is possible to factorize the two previous function into one, DeepHyper interface requires a function which returns `(train_inputs, train_outputs), (valid_inputs, valid_outputs)`.
#
# </div>
#
# We can give a visualization of this data:

# %% [markdown]
# ## Baseline Neural Network <a class="anchor" id="baseline-neural-network"></a>
#
# Let us define a baseline neural network based on a regular multi-layer perceptron architecture which learn the mean estimate and minimise the mean squared error.

# %%
if 0:
    input_ = tf.keras.layers.Input(shape=(s_x.shape[1],))
    out = tf.keras.layers.Dense(200, activation="relu")(input_)
    out = tf.keras.layers.Dense(200, activation="relu")(out)
    output = tf.keras.layers.Dense(1)(out)
    model = tf.keras.Model(input_, output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
    model.compile(optimizer, "mse")

    history = model.fit(s_x, s_y, epochs=200, batch_size=4, validation_data=(s_vx, s_vy), verbose=1).history

# %% [markdown]
# We can do a vizualisation of our learning curves to make sure the training and validation loss decrease correctly.

# %%
if 0:
    width = 8
    height = width/1.618
    plt.figure(figsize=(width, height))

    plt.plot(history["loss"], label="training")
    plt.plot(history["val_loss"], label="validation")

    plt.xlabel("Epochs")
    plt.ylabel("MSE")

    plt.legend()

    plt.show()

# %% [markdown]
# Also, let us look at the prediction on the test set after reversing the scaling of predicted variables.

# %% [markdown]
# ## Define the Neural Architecture Search Space <a class="anchor" id="define-the-neural-architecture-search-space"></a>
#
# The neural architecture search space is composed of discrete decision variables. For each decision variable we choose among a list of possible operation to perform (e.g., fully connected, ReLU). To define this search space, it is necessary to use two classes:
#
# * `KSearchSpace` (for Keras Search Space): represents a directed acyclic graph (DAG) in which each node represents a chosen operation. It represents the possible neural networks that can be created.
# * `SpaceFactory`: is a utilitiy class used to pack the logic of a search space definition and share it with others.
#
# Then, inside a `KSearchSpace` we will have two types of nodes:
# * `VariableNode`: corresponds to discrete decision variables and are used to define a list of possible operation.
# * `ConstantNode`: corresponds to fixed operation in the search space (e.g., input/outputs)
#
# Finally, it is possible to reuse any `tf.keras.layers` to define a `KSearchSpace`. However, it is important to wrap each layer in an `operation` to perform a lazy memory allocation of tensors.

# %%
if 1:
    import collections

    from deephyper.nas import KSearchSpace

    # Decision variables are represented by nodes in a graph
    from deephyper.nas.node import ConstantNode, VariableNode

    # The "operation" creates a wrapper around Keras layers avoid allocating 
    # memory each time a new layer is defined in the search space
    # For Skip/Residual connections we use "Zero", "Connect" and "AddByProjecting"
    from deephyper.nas.operation import operation, Zero, Connect, AddByProjecting, Identity

    Dense = operation(tf.keras.layers.Dense)

    # Possible activation functions
    ACTIVATIONS = [
        tf.keras.activations.elu,
        tf.keras.activations.gelu,
        tf.keras.activations.hard_sigmoid,
        tf.keras.activations.linear,
        tf.keras.activations.relu,
        tf.keras.activations.selu,
        tf.keras.activations.sigmoid,
        tf.keras.activations.softplus,
        tf.keras.activations.softsign,
        tf.keras.activations.swish,
        tf.keras.activations.tanh,
    ]

# %% [markdown]
# We implement the constructor `__init__` and `build` method of the `RegressionSpace` a subclass of `KSearchSpace`. The `__init__` method interface is:
#
# ```python
# def __init__(self, input_shape, output_shape, **kwargs):
#     ...
# ```
#
# for the `build` method the interface is:
#
# ```python
# def build(self):
#     ...
#     return self
# ```
#
# where:
# * `input_shape` corresponds to a tuple or a list of tuple indicating the shapes of inputs tensors.
# * `output_shape` corresponds to the same but of output_tensors.
# * `**kwargs` denotes that any other key word argument can be defined by the user.

# %%
if 1:
    class RegressionSpace(KSearchSpace):

        def __init__(self, input_shape, output_shape, seed=None, num_layers=3):
            super().__init__(input_shape, output_shape, seed=seed)

            self.num_layers = 3

        def build(self):

            # After creating a KSearchSpace nodes corresponds to the inputs are directly accessible
            out_sub_graph = self.build_sub_graph(self.input_nodes[0], self.num_layers)

            output = ConstantNode(op=Dense(self.output_shape[0]))  
            self.connect(out_sub_graph, output)

            return self

        def build_sub_graph(self, input_node, num_layers=3):


            # Look over skip connections within a range of the 3 previous nodes
            anchor_points = collections.deque([input_node], maxlen=3)

            prev_node = input_node

            for _ in range(num_layers):

                # Create a variable node to list possible "Dense" layers
                dense = VariableNode()

                # Add the possible operations to the dense node
                self.add_dense_to_(dense)

                # Connect the previous node to the dense node
                self.connect(prev_node, dense)

                # Create a constant node to merge all input connections
                merge = ConstantNode()
                merge.set_op(
                    AddByProjecting(self, [dense], activation="relu")
                )

                for node in anchor_points:

                    # Create a variable node for each possible connection
                    skipco = VariableNode()

                    skipco.add_op(Zero()) # corresponds to no connection
                    skipco.add_op(Connect(self, node)) # corresponds to (node => skipco)

                    # Connect the (skipco => merge)
                    self.connect(skipco, merge)


                # ! for next iter
                prev_node = merge
                anchor_points.append(prev_node)

            return prev_node

        def add_dense_to_(self, node):

            # We add the "Identity" operation to allow the choice "doing nothing"
            node.add_op(Identity())

            step = 16
            for units in range(step, step * 16 + 1, step):
                for activation in ACTIVATIONS:
                    node.add_op(Dense(units=units, activation=activation))

# %% [markdown]
# Let us visualize a few randomly sampled neural architecture from this search space.

# %%
if 0:
    import matplotlib.image as mpimg
    from tensorflow.keras.utils import plot_model

    shapes = dict(input_shape=(1,), output_shape=(1,))
    space = RegressionSpace(**shapes).build()


    images = []
    plt.figure(figsize=(15,15))
    for i in range(4):

        model = space.sample()
        plt.subplot(2,2,i+1)
        plot_model(model, "random_model.png", show_shapes=False, show_layer_names=False)
        image = mpimg.imread("random_model.png")
        plt.imshow(image)
        plt.axis('off')

    plt.show()

# %% [markdown]
# ## Define the Neural Architecture Optimization Problem <a class="anchor" id="define-the-neural-architecture-search-optimization-problem"></a>
#
# In order to define a neural architecture search problem we have to use the `NaProblem` class. This class gives access to different method for the user to customize the training settings of neural networks.

# %%
if 1:
    from deephyper.problem import NaProblem


    def stdscaler():
        return StandardScaler()


    problem = NaProblem()

    # Bind a function which returns (train_input, train_output), (valid_input, valid_output)
    problem.load_data(load_data_train_valid)

    # Bind a function which return a scikit-learn preprocessor (with fit, fit_transform, inv_transform...etc)
    #problem.preprocessing(stdscaler)

    # Bind a function which returns a search space and give some arguments for the `build` method
    problem.search_space(RegressionSpace, num_layers=3)

    # Define a set of fixed hyperparameters for all trained neural networks
    problem.hyperparameters(
        batch_size=4,
        learning_rate=1e-3,
        optimizer="adam",
        num_epochs=200,
        callbacks=dict(
            EarlyStopping=dict(monitor="val_loss", mode="min", verbose=0, patience=30)
        ),
    )

    # Define the loss to minimize
    problem.loss("mse")

    # Define complementary metrics
    problem.metrics([])

    # Define the maximized objective. Here we take the negative of the validation loss.
    problem.objective("-val_loss")

    problem

# %% [markdown]
# <div class="alert alert-info">
#
# <b>Tip</b>
#
# Adding an `EarlyStopping(...)` callback is a good idea to stop the training of your model as soon as it stops to improve.
#
# ```python
# ...
# EarlyStopping=dict(monitor="val_loss", mode="min", verbose=0, patience=30)
# ...
# ```
#
# </div>

# %% [markdown]
# ## Define the Evaluator Object
#
# The `Evaluator` object is responsible of defining the backend used to distribute the function evaluation in DeepHyper.

# %%
from deephyper.evaluator import Evaluator
from deephyper.evaluator.callback import LoggerCallback


def get_evaluator(run_function):
    
    # Default arguments for Ray: 1 worker and 1 worker per evaluation
    method_kwargs = {
        "num_cpus": 1, 
        "num_cpus_per_task": 1,
        "callbacks": [LoggerCallback()] # To interactively follow the finished evaluations,
    }

    # If GPU devices are detected then it will create 'n_gpus' workers
    # and use 1 worker for each evaluation
    if is_gpu_available:
        method_kwargs["num_cpus"] = n_gpus
        method_kwargs["num_gpus"] = n_gpus
        method_kwargs["num_cpus_per_task"] = 1
        method_kwargs["num_gpus_per_task"] = 1

    evaluator = Evaluator.create(
        run_function, 
        method="ray", 
        method_kwargs=method_kwargs
    )
    print(f"Created new evaluator with {evaluator.num_workers} worker{'s' if evaluator.num_workers > 1 else ''} and config: {method_kwargs}", )
    
    return evaluator

# %% [markdown]
# For neural architecture search a standard training pipeline is provided by the `run_base_trainer` function from the `deephyper.nas.run` module.

# %%
from deephyper.nas.run import run_base_trainer

# %% [markdown]
# ## Define and Run the Neural Architecture Search
#
# All search algorithms follow a similar interface. A `problem` and `evaluator` object has to be provided to the search then the search can be executed through the `search(max_evals, timeout)` method.

# %%
if 0:
    results = {} # used to store the results of different search algorithms
    max_evals = 10 # maximum number of iteratins for all searches

# %%
if 0:
    from deephyper.search.nas import Random

    random_search = Random(problem, get_evaluator(run_base_trainer), log_dir="random_search")

    results["random"] = random_search.search(max_evals=max_evals)

# %% [markdown]
# By default, the `RegularizedEvolution` has a population size of 100 therefore, it will start optimizing only after 100 evaluations.

# %%
if 0:
    from deephyper.search.nas import RegularizedEvolution

    regevo_search = RegularizedEvolution(problem, get_evaluator(run_base_trainer), log_dir="regevo_search")

    results["regevo"] = regevo_search.search(max_evals=max_evals)

# %% [markdown]
# We can now compare the search trajectories for different algorithms.

# %%
if 0:
    def max_score(l):
        r = [l[0]]
        for el in l[1:]:
            r.append(max(r[-1], el))
        return r

    width = 8
    height = width/1.618
    plt.figure(figsize=(width, height))

    for k, result in results.items():
        plt.plot(max_score(results[k].objective), label=k)

    plt.legend()

    plt.show()

# %% [markdown]
# If we look at the dataframe of results for each search we will find it slightly different than the one of hyperparameter search. A new column `arch_seq` corresponds to an embedding for each evaluated architecture. Each integer of an `arch_seq` list corresponds to the choice of a `VariableNode` in our `KSearchSpace`.

# %%
#results["random"]

# %% [markdown]
# Let us visualize the best architecture found:

# %%
if 0:
    i_max = results["random"].objective.argmax()
    best_score = results["random"].iloc[i_max].objective
    best_arch_seq = json.loads(results["random"].iloc[i_max].arch_seq)

    best_model = space.sample(best_arch_seq)
    plot_model(best_model, show_shapes=True, show_layer_names=False)

# %% [markdown]
# ## Adding Uncertainty Quantification to the Baseline Neural Network
#
# To add uncertainty estimates we use the [Tensorflow Probability](https://www.tensorflow.org/probability) library which is fully compatible with the neural architecture search API because it is accessible through Keras layers.

# %%
if 1:
    import tensorflow_probability as tfp
    tfd = tfp.distributions

# %% [markdown]
# Then, instead of minimising the mean squared error we will minimize the negative log-likelihood baed on the learned probability distribution $p(y|\mathbf{x};\theta)$ where $\theta$ represents a neural network (architecture, training hyperparameters, weights).

# %%
if 1:
    def nll(y, rv_y):
        """Negative log likelihood for Tensorflow probability.

        Args:
            y: true data.
            rv_y: learned (predicted) probability distribution.
        """
        return -rv_y.log_prob(y)

# %% [markdown]
# Let us visualize the learned uncertainty estimates.

# %% [markdown]
# The learned mean estimates appears to be worse than when minimizing the mean squared error loss. Also, we can see than the variance estimate are not meaningful in areas missing data (white background) and do not learn properly the noise in are with data (grey background).

# %% [markdown]
# ## Ensemble of Neural Networks With Random Initialization

# %% [markdown]
# The `UQBaggingEnsembleRegressor` provides different strategies to build ensemble of neural networks from a library of saved models. The computation is distributed with Ray (for the inference and ranking of ensemble members).

# %%
if 1:
    from deephyper.ensemble import UQBaggingEnsembleRegressor

    ensemble = UQBaggingEnsembleRegressor(
        model_dir="models_random_init",
        loss=nll,  # default is nll
        size=5,
        verbose=True,
        ray_address="auto",
        num_cpus=1,
        num_gpus=1 if is_gpu_available else None,
        selection="topk",
    )

# %% [markdown]
# We can visualize the uncertainty estimate of such ensemble.

# %% [markdown]
# By using the **Law of Total Variance** we can decompose the aleatoric and epistemic components of the predicted uncertainty. With random-initialization we can see that epistemic uncertainty is almost null everywhere and not informative on area missing data (white background).

# %% [markdown]
# ## AutoDEUQ: Automated Deep Ensemble with Uncertainty Quantification
#
# AutoDEUQ is an algorithm in 2 steps:
# 1. joint hyperparameter and neural architecture search to generate a catalog of models.
# 2. build an ensemble from the catalog
#
# To this end we start by editing slightly the previous `RegressionFactory` by adding the `DistributionLambda` layer as output.

# %%
DistributionLambda = operation(tfp.layers.DistributionLambda)

# %%
class RegressionUQSpace(KSearchSpace):
    
    def __init__(self, input_shape, output_shape, seed=None, num_layers=3):
        super().__init__(input_shape, output_shape, seed=seed)
        
        self.num_layers = 3
    
    def build(self):

        out_sub_graph = self.build_sub_graph(self.input_nodes[0], self.num_layers)
        
        output_dim = self.output_shape[0]
        output_dense = ConstantNode(op=Dense(output_dim*2))  
        self.connect(out_sub_graph, output_dense)
        
        
        output_dist = ConstantNode(
            op=DistributionLambda(
                lambda t: tfd.Normal(
                    loc=t[..., :output_dim],
                    scale=1e-3 + tf.math.softplus(0.05 * t[..., output_dim:]),
                )
            )
        )
        self.connect(output_dense, output_dist)

        return self

    def build_sub_graph(self, input_node, num_layers=3):
        

        # Look over skip connections within a range of the 3 previous nodes
        anchor_points = collections.deque([input_node], maxlen=3)
        
        prev_node = input_node
        
        for _ in range(num_layers):
            
            # Create a variable node to list possible "Dense" layers
            dense = VariableNode()
            
            # Add the possible operations to the dense node
            self.add_dense_to_(dense)
            
            # Connect the previous node to the dense node
            self.connect(prev_node, dense)

            # Create a constant node to merge all input connections
            merge = ConstantNode()
            merge.set_op(
                AddByProjecting(self, [dense], activation="relu")
            )

            for node in anchor_points:
                
                # Create a variable node for each possible connection
                skipco = VariableNode()
                
                skipco.add_op(Zero()) # corresponds to no connection
                skipco.add_op(Connect(self, node)) # corresponds to (node => skipco)
                
                # Connect the (skipco => merge)
                self.connect(skipco, merge)

 
            # ! for next iter
            prev_node = merge
            anchor_points.append(prev_node)

        return prev_node

    def add_dense_to_(self, node):
        
        # We add the "Identity" operation to allow the choice "doing nothing"
        node.add_op(Identity())
        
        step = 16
        for units in range(step, step * 16 + 1, step):
            for activation in ACTIVATIONS:
                node.add_op(Dense(units=units, activation=activation))

# %% [markdown]
# For joint hyperparameter and neural architecture search it is possible to use the `problem.add_hyperparameter(...)` to define variable hyperparameters in the NAS Problem.

# %%
problem_uq = NaProblem()

problem_uq.load_data(load_data_train_valid)

#problem_uq.preprocessing(stdscaler)

problem_uq.search_space(RegressionUQSpace, num_layers=3)

problem_uq.hyperparameters(
    batch_size=problem_uq.add_hyperparameter((1, 32), "batch_size"),
    learning_rate=problem_uq.add_hyperparameter(
        (1e-4, 0.1, "log-uniform"),
        "learning_rate",
    ),
    optimizer=problem_uq.add_hyperparameter(
        ["sgd", "rmsprop", "adagrad", "adam", "adadelta", "adamax", "nadam"],
        "optimizer",
    ),
    patience_ReduceLROnPlateau=problem_uq.add_hyperparameter(
        (10, 20), "patience_ReduceLROnPlateau"
    ),
    patience_EarlyStopping=problem_uq.add_hyperparameter(
        (20, 30), "patience_EarlyStopping"
    ),
    num_epochs=200,
    callbacks=dict(
        ReduceLROnPlateau=dict(monitor="val_loss", mode="min", verbose=0, patience=5),
        EarlyStopping=dict(monitor="val_loss", mode="min", verbose=0, patience=10),
        # We save trained models in neural architecture search
        ModelCheckpoint=dict(
            monitor="val_loss",
            mode="min",
            save_best_only=True,
            verbose=0,
            filepath="model.h5",
            save_weights_only=False,
        ),
    ),
)

problem_uq.loss(nll)

problem_uq.metrics([])

# The objective is maximized so we take the negative of the validation loss
# where the loss is minimized
problem_uq.objective("-val_loss")

problem_uq
# Out:
# Problem is:
#     - search space   : __main__.RegressionUQSpace
#     - data loading   : __main__.load_data_train_valid
#     - preprocessing  : None
#     - hyperparameters:
#         * verbose: 0
#         * batch_size: batch_size, Type: UniformInteger, Range: [1, 32], Default: 16
#         * learning_rate: learning_rate, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#         * optimizer: optimizer, Type: Categorical, Choices: {sgd, rmsprop, adagrad, adam, adadelta, adamax, nadam}, Default: sgd
#         * patience_ReduceLROnPlateau: patience_ReduceLROnPlateau, Type: UniformInteger, Range: [10, 20], Default: 15
#         * patience_EarlyStopping: patience_EarlyStopping, Type: UniformInteger, Range: [20, 30], Default: 25
#         * num_epochs: 200
#         * callbacks: {'ReduceLROnPlateau': {'monitor': 'val_loss', 'mode': 'min', 'verbose': 0, 'patience': 5}, 'EarlyStopping': {'monitor': 'val_loss', 'mode': 'min', 'verbose': 0, 'patience': 10}, 'ModelCheckpoint': {'monitor': 'val_loss', 'mode': 'min', 'save_best_only': True, 'verbose': 0, 'filepath': 'model.h5', 'save_weights_only': False}}
#     - loss           : <function nll at 0x3b059c7c0>
#     - metrics        :
#     - objective      : -val_loss

# %%
results_uq = {}

# %% [markdown]
# The `max_evals` has to be superior or equal to 400 to start having a good UQ estimate.

# %%
from deephyper.search.nas import AgEBO


load_from_checkpoint = True
if not(load_from_checkpoint):
    
    if os.path.exists("agebo_search"):
        shutil.rmtree("agebo_search")
        
    # "n_jobs" is the number of processes used to refresh the state of the surrogate model used in AgEBO 
    agebo_search = AgEBO(problem_uq, get_evaluator(run_base_trainer), log_dir="agebo_search", n_jobs=4)

    results_uq["agebo"] = agebo_search.search(max_evals=150)
# Out:
# /Users/p12/deephyper/deephyper/evaluator/_evaluator.py:130: UserWarning: Applying nest-asyncio patch for IPython Shell!
#   warnings.warn(
# Created new evaluator with 1 worker and config: {'num_cpus': 1, 'num_cpus_per_task': 1, 'callbacks': [<deephyper.evaluator.callback.LoggerCallback object at 0x3b2e02190>]}
# [00001] -- best objective: 0.03395 -- received objective: 0.03395
# [00002] -- best objective: 0.03395 -- received objective: -0.06812
# [00003] -- best objective: 0.03395 -- received objective: -0.57209
# [00004] -- best objective: 1.25701 -- received objective: 1.25701
# [00005] -- best objective: 1.25701 -- received objective: 0.20252
# [00006] -- best objective: 1.25701 -- received objective: 0.71940
# [00007] -- best objective: 1.25701 -- received objective: 0.14439
# [00008] -- best objective: 1.92282 -- received objective: 1.92282
# [00009] -- best objective: 1.92282 -- received objective: 1.62220
# [00010] -- best objective: 1.92282 -- received objective: 0.69808
# [00011] -- best objective: 1.92282 -- received objective: 0.63515
# [00012] -- best objective: 1.92282 -- received objective: 1.58613
# [00013] -- best objective: 1.92282 -- received objective: 1.23595
# [00014] -- best objective: 1.92282 -- received objective: 0.94146
# [00015] -- best objective: 1.92282 -- received objective: 0.49184
# [00016] -- best objective: 1.98259 -- received objective: 1.98259
# [00017] -- best objective: 1.98259 -- received objective: 1.90757
# [00018] -- best objective: 1.98259 -- received objective: 0.93288
# [00019] -- best objective: 2.02877 -- received objective: 2.02877
# [00020] -- best objective: 2.02877 -- received objective: 0.99846
# [00021] -- best objective: 2.07956 -- received objective: 2.07956
# [00022] -- best objective: 2.07956 -- received objective: 1.78752
# [00023] -- best objective: 2.07956 -- received objective: 0.81479
# [00024] -- best objective: 2.07956 -- received objective: 0.52825
# [00025] -- best objective: 2.07956 -- received objective: 1.26450
# [00026] -- best objective: 2.07956 -- received objective: 1.34088
# [00027] -- best objective: 2.07956 -- received objective: 1.35880
# [00028] -- best objective: 2.32516 -- received objective: 2.32516
# [00029] -- best objective: 2.32516 -- received objective: 2.19591
# [00030] -- best objective: 2.32516 -- received objective: 1.66801
# [00031] -- best objective: 2.32516 -- received objective: 1.97670
# [00032] -- best objective: 2.32516 -- received objective: 1.74856
# [00033] -- best objective: 2.32516 -- received objective: 1.72806
# [00034] -- best objective: 2.32516 -- received objective: 2.13039
# [00035] -- best objective: 2.32516 -- received objective: 0.89327
# [00036] -- best objective: 2.32570 -- received objective: 2.32570
# [00037] -- best objective: 2.32570 -- received objective: 1.14530
# [00038] -- best objective: 2.32570 -- received objective: 2.20986
# [00039] -- best objective: 2.32570 -- received objective: 1.28010
# [00040] -- best objective: 2.32570 -- received objective: 1.47868
# [00041] -- best objective: 2.32570 -- received objective: 2.18625
# [00042] -- best objective: 2.32570 -- received objective: 0.33728
# [00043] -- best objective: 2.32570 -- received objective: 2.15231
# [00044] -- best objective: 2.32570 -- received objective: 0.65377
# [00045] -- best objective: 2.32570 -- received objective: 2.05313
# [00046] -- best objective: 2.32570 -- received objective: 2.18190
# [00047] -- best objective: 2.32570 -- received objective: 1.96295
# [00048] -- best objective: 2.32570 -- received objective: 0.68124
# [00049] -- best objective: 2.32570 -- received objective: 1.60951
# [00050] -- best objective: 2.32570 -- received objective: 1.58949
# [00051] -- best objective: 2.32570 -- received objective: 2.17357
# [00052] -- best objective: 2.32570 -- received objective: 2.25537
# [00053] -- best objective: 2.32570 -- received objective: 1.96855
# [00054] -- best objective: 2.32570 -- received objective: 1.60094
# [00055] -- best objective: 2.32570 -- received objective: 1.91819
# [00056] -- best objective: 2.32570 -- received objective: 1.89400
# [00057] -- best objective: 2.32570 -- received objective: 1.55488
# [00058] -- best objective: 2.32570 -- received objective: 1.72700
# [00059] -- best objective: 2.32570 -- received objective: 2.24147
# [00060] -- best objective: 2.32570 -- received objective: 2.23899
# [00061] -- best objective: 2.32570 -- received objective: 1.33211
# [00062] -- best objective: 2.32570 -- received objective: 2.02895
# [00063] -- best objective: 2.32570 -- received objective: 1.52976
# [00064] -- best objective: 2.32570 -- received objective: 1.82174
# [00065] -- best objective: 2.32570 -- received objective: 1.10536
# [00066] -- best objective: 2.32570 -- received objective: 2.02472
# [00067] -- best objective: 2.32570 -- received objective: 1.43330
# [00068] -- best objective: 2.32570 -- received objective: 2.19896
# [00069] -- best objective: 2.32570 -- received objective: 0.18208
# [00070] -- best objective: 2.32570 -- received objective: 2.15946
# [00071] -- best objective: 2.32570 -- received objective: 1.74159
# [00072] -- best objective: 2.32570 -- received objective: 1.97676
# [00073] -- best objective: 2.32570 -- received objective: 2.09825
# [00074] -- best objective: 2.37497 -- received objective: 2.37497
# [00075] -- best objective: 2.37497 -- received objective: 1.78222
# [00076] -- best objective: 2.37497 -- received objective: 0.94541
# [00077] -- best objective: 2.37497 -- received objective: 2.09707
# [00078] -- best objective: 2.37497 -- received objective: 2.07665
# [00079] -- best objective: 2.37497 -- received objective: 2.12814
# [00080] -- best objective: 2.37497 -- received objective: 1.98247
# [00081] -- best objective: 2.37497 -- received objective: 2.14128
# [00082] -- best objective: 2.37497 -- received objective: 1.79992
# [00083] -- best objective: 2.37497 -- received objective: 1.76590
# [00084] -- best objective: 2.37497 -- received objective: 1.89239
# [00085] -- best objective: 2.37497 -- received objective: 1.89326
# [00086] -- best objective: 2.37497 -- received objective: 1.78361
# [00087] -- best objective: 2.37497 -- received objective: 1.91879
# [00088] -- best objective: 2.37497 -- received objective: 2.01589
# [00089] -- best objective: 2.37497 -- received objective: 1.81103
# [00090] -- best objective: 2.37497 -- received objective: 2.04328
# [00091] -- best objective: 2.37497 -- received objective: 1.85391
# [00092] -- best objective: 2.37497 -- received objective: 2.00418
# [00093] -- best objective: 2.37497 -- received objective: 1.96437
# [00094] -- best objective: 2.37497 -- received objective: 1.62059
# [00095] -- best objective: 2.37497 -- received objective: 1.65459
# [00096] -- best objective: 2.37497 -- received objective: 1.90029
# [00097] -- best objective: 2.37497 -- received objective: 1.80457
# [00098] -- best objective: 2.37497 -- received objective: 1.50425
# [00099] -- best objective: 2.37497 -- received objective: 2.01453
# [00100] -- best objective: 2.37497 -- received objective: 1.88943
# [00101] -- best objective: 2.37497 -- received objective: 1.79591
# [00102] -- best objective: 2.52120 -- received objective: 2.52120
# [00103] -- best objective: 2.52120 -- received objective: 1.78421
# [00104] -- best objective: 2.52120 -- received objective: 1.58867
# [00105] -- best objective: 2.52120 -- received objective: 2.02411
# [00106] -- best objective: 2.52120 -- received objective: 1.88714
# [00107] -- best objective: 2.52120 -- received objective: 1.81486
# [00108] -- best objective: 2.52120 -- received objective: 1.85916
# [00109] -- best objective: 2.52120 -- received objective: 2.02524
# [00110] -- best objective: 2.52120 -- received objective: 1.92809
# [00111] -- best objective: 2.52120 -- received objective: 2.14209
# [00112] -- best objective: 2.52120 -- received objective: 2.05758
# [00113] -- best objective: 2.52120 -- received objective: 1.41137
# [00114] -- best objective: 2.52120 -- received objective: 2.00431
# [00115] -- best objective: 2.52120 -- received objective: 2.27351
# [00116] -- best objective: 2.52120 -- received objective: 1.95354
# [00117] -- best objective: 2.52120 -- received objective: 1.76954
# [00118] -- best objective: 2.52120 -- received objective: 1.86214
# [00119] -- best objective: 2.52120 -- received objective: 1.70999
# [00120] -- best objective: 2.52120 -- received objective: 1.56225
# [00121] -- best objective: 2.52120 -- received objective: 1.91710
# [00122] -- best objective: 2.52120 -- received objective: 1.30428
# [00123] -- best objective: 2.52120 -- received objective: 1.12485
# [00124] -- best objective: 2.52120 -- received objective: 2.10348
# [00125] -- best objective: 2.52120 -- received objective: 1.99663
# [00126] -- best objective: 2.52120 -- received objective: 2.05879
# [00127] -- best objective: 2.52120 -- received objective: 1.74233
# [00128] -- best objective: 2.52120 -- received objective: 2.27300
# [00129] -- best objective: 2.52120 -- received objective: 1.96209
# [00130] -- best objective: 2.52120 -- received objective: 1.95409
# [00131] -- best objective: 2.52120 -- received objective: 2.19703
# [00132] -- best objective: 2.52120 -- received objective: 2.09026
# [00133] -- best objective: 2.52120 -- received objective: 1.63874
# [00134] -- best objective: 2.52120 -- received objective: 1.89636
# [00135] -- best objective: 2.52120 -- received objective: 1.71395
# [00136] -- best objective: 2.52120 -- received objective: 1.93317
# [00137] -- best objective: 2.52120 -- received objective: 1.72233
# [00138] -- best objective: 2.52120 -- received objective: 1.39875
# [00139] -- best objective: 2.52120 -- received objective: 2.12869
# [00140] -- best objective: 2.52120 -- received objective: 1.50997
# [00141] -- best objective: 2.52120 -- received objective: 2.19733
# [00142] -- best objective: 2.52120 -- received objective: 2.03137
# [00143] -- best objective: 2.52120 -- received objective: 1.89115
# [00144] -- best objective: 2.52120 -- received objective: 2.01337
# [00145] -- best objective: 2.52120 -- received objective: 2.09089
# [00146] -- best objective: 2.52120 -- received objective: 1.79265
# [00147] -- best objective: 2.52120 -- received objective: 2.31277
# [00148] -- best objective: 2.52120 -- received objective: 1.71912
# [00149] -- best objective: 2.52120 -- received objective: 1.75608
# [00150] -- best objective: 2.52120 -- received objective: 2.16780

# %%
if not(load_from_checkpoint):
    results_uq["agebo"]

# %% [markdown]
# Different sizes of ensemble and two selection strategies can be experimented for ensembles:
# * `caruana`: a greedy selection from Caruana based on the loss function.
# * `topk`: select the top-k (i.e., `size`) best models based on the loss function.

# %%
ensemble = UQBaggingEnsembleRegressor(
    model_dir="agebo_search/save/model",
    loss=nll,  # default is nll
    size=10,
    verbose=True,
    ray_address="auto",
    num_cpus=1,
    num_gpus=1 if is_gpu_available else None,
    selection="caruana",
)

if load_from_checkpoint:
    ensemble.load("agebo_search/ensemble.json")
else:
    ensemble.fit(s_vx, s_vy)
    ensemble.save("agebo_search/ensemble.json")

print(f"Selected {len(ensemble.members_files)} members are: ", ensemble.members_files)
# Out:
# Selected 6 members are:  ['0.101.h5', '0.27.h5', '0.108.h5', '0.101.h5', '0.27.h5', '0.101.h5']

# %%
import json

members_infos = {}
print("Number of parameters of ensemble members: ")
for member_file in set(ensemble.members_files):
    member_id = member_file[:-3]
    with open(f"agebo_search/save/history/{member_id}.json", "r") as fp:
        members_infos[member_id] = json.load(fp)
        print(f" - id:{member_id} -> {members_infos[member_id]['n_parameters']} parameters")
# Out:
# Number of parameters of ensemble members:
#  - id:0.101 -> 71410 parameters
#  - id:0.27 -> 91154 parameters
#  - id:0.108 -> 137074 parameters

# %%
import matplotlib.image as mpimg
import tensorflow as tf
from tensorflow.keras.utils import plot_model

for member_file in set(ensemble.members_files):
    member_id = member_file[:-3]
    
    model_path = f"agebo_search/save/model/{member_id}.h5"
    model = tf.keras.models.load_model(model_path, compile=False)
    
    print(f" - id:{member_id} -> {len(model.layers)} layers")
    
    model.summary()
    
    plt.figure(figsize=(3,8))
    plot_model(model, "model.png", show_shapes=True, show_layer_names=True)
    image = mpimg.imread("random_model.png")
    plt.imshow(image)
    plt.axis('off')
    plt.show()
# Out:
#  - id:0.101 -> 12 layers
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_0 (InputLayer)        [(None, 100)]                0         []
#
#  dense (Dense)               (None, 176)                  17776     ['input_0[0][0]']
#
#  dense_1 (Dense)             (None, 176)                  17776     ['input_0[0][0]']
#
#  add (Add)                   (None, 176)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]']
#
#  activation (Activation)     (None, 176)                  0         ['add[0][0]']
#
#  dense_2 (Dense)             (None, 144)                  25488     ['activation[0][0]']
#
#  dense_3 (Dense)             (None, 32)                   4640      ['dense_2[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   5664      ['activation[0][0]']
#
#  add_1 (Add)                 (None, 32)                   0         ['dense_3[0][0]',
#                                                                      'dense_4[0][0]']
#
#  activation_1 (Activation)   (None, 32)                   0         ['add_1[0][0]']
#
#  dense_5 (Dense)             (None, 2)                    66        ['activation_1[0][0]']
#
#  distribution_lambda (Distr  ((None, 1),                  0         ['dense_5[0][0]']
#  ibutionLambda)               (None, 1))
#
# ==================================================================================================
# Total params: 71410 (278.95 KB)
# Trainable params: 71410 (278.95 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
#  - id:0.27 -> 12 layers
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_0 (InputLayer)        [(None, 100)]                0         []
#
#  dense (Dense)               (None, 80)                   8080      ['input_0[0][0]']
#
#  dense_1 (Dense)             (None, 80)                   8080      ['input_0[0][0]']
#
#  add (Add)                   (None, 80)                   0         ['dense[0][0]',
#                                                                      'dense_1[0][0]']
#
#  activation (Activation)     (None, 80)                   0         ['add[0][0]']
#
#  dense_2 (Dense)             (None, 208)                  16848     ['activation[0][0]']
#
#  dense_3 (Dense)             (None, 208)                  21008     ['input_0[0][0]']
#
#  add_1 (Add)                 (None, 208)                  0         ['dense_2[0][0]',
#                                                                      'dense_3[0][0]']
#
#  activation_1 (Activation)   (None, 208)                  0         ['add_1[0][0]']
#
#  dense_4 (Dense)             (None, 176)                  36784     ['activation_1[0][0]']
#
#  dense_5 (Dense)             (None, 2)                    354       ['dense_4[0][0]']
#
#  distribution_lambda (Distr  ((None, 1),                  0         ['dense_5[0][0]']
#  ibutionLambda)               (None, 1))
#
# ==================================================================================================
# Total params: 91154 (356.07 KB)
# Trainable params: 91154 (356.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
#  - id:0.108 -> 12 layers
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_0 (InputLayer)        [(None, 100)]                0         []
#
#  dense (Dense)               (None, 192)                  19392     ['input_0[0][0]']
#
#  dense_1 (Dense)             (None, 192)                  19392     ['input_0[0][0]']
#
#  add (Add)                   (None, 192)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]']
#
#  activation (Activation)     (None, 192)                  0         ['add[0][0]']
#
#  dense_2 (Dense)             (None, 208)                  40144     ['activation[0][0]']
#
#  dense_3 (Dense)             (None, 208)                  21008     ['input_0[0][0]']
#
#  add_1 (Add)                 (None, 208)                  0         ['dense_2[0][0]',
#                                                                      'dense_3[0][0]']
#
#  activation_1 (Activation)   (None, 208)                  0         ['add_1[0][0]']
#
#  dense_4 (Dense)             (None, 176)                  36784     ['activation_1[0][0]']
#
#  dense_5 (Dense)             (None, 2)                    354       ['dense_4[0][0]']
#
#  distribution_lambda (Distr  ((None, 1),                  0         ['dense_5[0][0]']
#  ibutionLambda)               (None, 1))
#
# ==================================================================================================
# Total params: 137074 (535.45 KB)
# Trainable params: 137074 (535.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
if 0:
    import matplotlib.image as mpimg
    from tensorflow.keras.utils import plot_model

    shapes = dict(input_shape=(1,), output_shape=(1,))
    space = RegressionSpace(**shapes).build()


    images = []
    plt.figure(figsize=(15,15))
    for i in range(4):

        model = space.sample()
        plt.subplot(2,2,i+1)
        plot_model(model, "random_model.png", show_shapes=False, show_layer_names=False)
        image = mpimg.imread("random_model.png")
        plt.imshow(image)
        plt.axis('off')

    plt.show()

# %%
#s_x = x
#s_y = y
#s_vx = vx
#s_vy = vy

# %%
#import matplotlib
#matplotlib.rcParams.update(matplotlib.rcParamsDefault)

# %%
pred_s_ty, pred_s_ty_aleatoric_var, pred_s_ty_epistemic_var = ensemble.predict_var_decomposition(s_x)

pred_ty_mean = pred_s_ty.loc.numpy() 
pred_ty_aleatoric_var = pred_s_ty_aleatoric_var 
pred_ty_epistemic_var = pred_s_ty_epistemic_var

# %%
from sklearn.metrics import mean_squared_error, r2_score


y_true = preprocessor_output.inverse_transform(s_y).flatten()
y_pred = preprocessor_output.inverse_transform(pred_ty_mean).flatten()

rmse_train = mean_squared_error(y_true, y_pred, squared=False)
r2_train = r2_score(y_true, y_pred)

print(f"RMSE Training: {rmse_train:.3f}")
print(f"R2   Training: {r2_train:.3f}")
# Out:
# RMSE Training: 0.076
# R2   Training: 1.000

# %%
pred_s_ty, pred_s_ty_aleatoric_var, pred_s_ty_epistemic_var = ensemble.predict_var_decomposition(s_vx)

pred_ty_mean = pred_s_ty.loc.numpy() 
pred_ty_aleatoric_var = pred_s_ty_aleatoric_var 
pred_ty_epistemic_var = pred_s_ty_epistemic_var

# %%
from sklearn.metrics import mean_squared_error, r2_score


y_true = preprocessor_output.inverse_transform(s_vy).flatten()
y_pred = preprocessor_output.inverse_transform(pred_ty_mean).flatten()

rmse_valid = mean_squared_error(y_true, y_pred, squared=False)
r2_valid = r2_score(y_true, y_pred)

print(f"RMSE Training: {rmse_valid:.3f}")
print(f"R2   Training: {r2_valid:.3f}")
# Out:
# RMSE Training: 0.230
# R2   Training: 0.996

# %%
pred_s_ty, pred_s_ty_aleatoric_var, pred_s_ty_epistemic_var = ensemble.predict_var_decomposition(s_x)

pred_ty_mean = pred_s_ty.loc.numpy() 
pred_ty_aleatoric_var = pred_s_ty_aleatoric_var 
pred_ty_epistemic_var = pred_s_ty_epistemic_var

# %%
# 95.44% interval
pred_ty_aleatoric_interval = np.sqrt(pred_ty_aleatoric_var) 
pred_ty_epistemic_interval = np.sqrt(pred_ty_epistemic_var)
aleatoric_ub = preprocessor_output.inverse_transform(pred_ty_mean + pred_ty_aleatoric_interval)
mid = preprocessor_output.inverse_transform(pred_ty_mean)
aleatoric_error = aleatoric_ub - mid
epistemic_ub = preprocessor_output.inverse_transform(pred_ty_mean + pred_ty_epistemic_interval)
epistemic_error = epistemic_ub - mid

# %%
print(aleatoric_error.shape)
print(epistemic_error.shape)
print(preprocessor_output.inverse_transform(s_y).flatten().shape)
print(preprocessor_output.inverse_transform(pred_ty_mean).flatten().shape)
min_train = np.min(preprocessor_output.inverse_transform(s_y).flatten())
max_train = np.max(preprocessor_output.inverse_transform(s_y).flatten())
print(min_train)
# Out:
# (126, 1)
# (126, 1)
# (126,)
# (126,)
# -2319.66081293

# %%
plt.figure(figsize=(8,4))
plt.errorbar(preprocessor_output.inverse_transform(s_y).flatten(),
             preprocessor_output.inverse_transform(pred_ty_mean).flatten(),
             aleatoric_error.flatten(),
             fmt='o', color='black',
             ecolor='gray', elinewidth=2, capsize=0)
plt.plot(preprocessor_output.inverse_transform(s_y).flatten(),preprocessor_output.inverse_transform(s_y).flatten())
plt.xlabel("Observed energy values ", fontsize=15)
plt.ylabel(r"Predicted enegy values with" 
           "\n" r"aleatoric uncertainty",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.tight_layout()
#plt.axline([0, 0], [1, 1])
plt.savefig('train-ale-uq.png')

# %%
plt.figure(figsize=(8,4))
plt.errorbar(preprocessor_output.inverse_transform(s_y).flatten(),
             preprocessor_output.inverse_transform(pred_ty_mean).flatten(),
             epistemic_error.flatten(),
             fmt='o', color='black',
             ecolor='gray', elinewidth=2, capsize=0)
             #linestyle='None', marker='^')
plt.plot(preprocessor_output.inverse_transform(s_y).flatten(),preprocessor_output.inverse_transform(s_y).flatten())
plt.xlabel("Observed energy values", fontsize=15)
plt.ylabel(r"Predicted energy values with" 
           "\n" r"epistemic uncertainty",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.tight_layout()
#plt.axline([0, 0], [1, 1])
plt.savefig('train-epi-uq.png')

# %%
from matplotlib import pyplot

bins = np.arange(0.0,3.0,0.1)

plt.figure(figsize=(8,4))
pyplot.hist(aleatoric_error, bins, alpha=0.5, label='Aleatoric')
pyplot.hist(epistemic_error, bins, alpha=0.5, label='Epistemic')
pyplot.legend(loc='upper right',prop={'size': 15})
pyplot.xlabel("Uncertainty", fontsize=15)
pyplot.ylabel("Frequency",fontsize=15)
pyplot.xticks(fontsize=14)
pyplot.yticks(fontsize=14)
pyplot.grid()
pyplot.tight_layout()
pyplot.savefig('train-hist-uq.png')

# %%
pred_s_ty, pred_s_ty_aleatoric_var, pred_s_ty_epistemic_var = ensemble.predict_var_decomposition(X_test_PCA)

pred_ty_mean = pred_s_ty.loc.numpy() 
pred_ty_aleatoric_var = pred_s_ty_aleatoric_var 
pred_ty_epistemic_var = pred_s_ty_epistemic_var

# %%
# 95.44% interval
pred_ty_aleatoric_interval = np.sqrt(pred_ty_aleatoric_var) 
pred_ty_epistemic_interval = np.sqrt(pred_ty_epistemic_var) 
aleatoric_ub = preprocessor_output.inverse_transform(pred_ty_mean+pred_ty_aleatoric_interval)
epistemic_ub = preprocessor_output.inverse_transform(pred_ty_mean+pred_ty_epistemic_interval)
mid = preprocessor_output.inverse_transform(pred_ty_mean)
aleatoric_error = aleatoric_ub - mid
epistemic_error = epistemic_ub - mid

# %%
plt.figure(figsize=(8,4))
plt.errorbar(preprocessor_output.inverse_transform(pred_ty_mean).flatten(),
             preprocessor_output.inverse_transform(pred_ty_mean).flatten(),
             aleatoric_error.flatten(),
             fmt='o', color='black',
             ecolor='gray', elinewidth=2, capsize=0)
plt.axvline(x=min_train, color='r', linestyle='--')
plt.axvline(x=max_train, color='r', linestyle='--')
plt.xlabel("Predicted energy values", fontsize=15)
plt.ylabel(r"Predicted energy values with" 
           "\n" r"aleatoric uncertainty",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.tight_layout()
#plt.axline([0, 0], [1, 1])
plt.savefig('test-ale-uq.png')

# %%
plt.figure(figsize=(8,4))
plt.errorbar(preprocessor_output.inverse_transform(pred_ty_mean).flatten(),
             preprocessor_output.inverse_transform(pred_ty_mean).flatten(), 
             epistemic_error.flatten(),
             fmt='o', color='black',
             ecolor='gray', elinewidth=2, capsize=0)
plt.axvline(x=min_train, color='r', linestyle='--')
plt.axvline(x=max_train, color='r', linestyle='--')
plt.xlabel("Predicted values", fontsize=15)
plt.ylabel(r"Predicted values with" 
           "\n" r"epistemic uncertainty",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.tight_layout()
#plt.axline([0, 0], [1, 1])
plt.savefig('test-epi-uq.png')

# %%
if 0:
    plt.hist(aleatoric_error,bins=np.arange(0.0,5.0,0.1))
    plt.xlabel("Aleatoric uncertainty", fontsize=15)
    plt.ylabel("Frequency",fontsize=15)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid()
    plt.tight_layout()

# %%
if 0:
    plt.hist(epistemic_error,bins=np.arange(0.0,5.0,0.1))
    plt.xlabel("Epistemic uncertainty", fontsize=15)
    plt.ylabel("Frequency",fontsize=15)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid()
    plt.tight_layout()

# %%
from matplotlib import pyplot

bins = np.arange(0.0,3.0,0.1)

plt.figure(figsize=(8,4))
pyplot.hist(aleatoric_error, bins, alpha=0.5, label='Aleatoric')
pyplot.hist(epistemic_error, bins, alpha=0.5, label='Epistemic')
pyplot.legend(loc='upper right',prop={'size': 15})
pyplot.xlabel("Uncertainty", fontsize=15)
pyplot.ylabel("Frequency",fontsize=15)
pyplot.xticks(fontsize=14)
pyplot.yticks(fontsize=14)
pyplot.grid()
pyplot.tight_layout()
#pyplot.show()
pyplot.savefig('test-hist-uq.png')

# %%
pred_s_ty, pred_s_ty_aleatoric_var, pred_s_ty_epistemic_var = ensemble.predict_var_decomposition(s_vx)

pred_ty_mean = pred_s_ty.loc.numpy() 
pred_ty_aleatoric_var = pred_s_ty_aleatoric_var 
pred_ty_epistemic_var = pred_s_ty_epistemic_var

# %%
# 95.44% interval
pred_ty_aleatoric_interval = np.sqrt(pred_ty_aleatoric_var) 
pred_ty_epistemic_interval = np.sqrt(pred_ty_epistemic_var) 
aleatoric_ub = preprocessor_output.inverse_transform(pred_ty_mean+pred_ty_aleatoric_interval)
mid = preprocessor_output.inverse_transform(pred_ty_mean)
aleatoric_error = aleatoric_ub - mid
epistemic_ub = preprocessor_output.inverse_transform(pred_ty_mean+pred_ty_epistemic_interval)
epistemic_error = epistemic_ub - mid

# %%
print(aleatoric_error.shape)
print(epistemic_error.shape)
print(preprocessor_output.inverse_transform(s_vy).flatten().shape)
print(preprocessor_output.inverse_transform(pred_ty_mean).flatten().shape)
# Out:
# (63, 1)
# (63, 1)
# (63,)
# (63,)

# %%
plt.figure(figsize=(8,4))
plt.errorbar(preprocessor_output.inverse_transform(s_vy).flatten(),
             preprocessor_output.inverse_transform(pred_ty_mean).flatten(),
             aleatoric_error.flatten(),
             fmt='o', color='black',
             ecolor='gray', elinewidth=2, capsize=0)
plt.plot(preprocessor_output.inverse_transform(s_vy).flatten(),preprocessor_output.inverse_transform(s_vy).flatten())
plt.xlabel("Observed energy values ", fontsize=15)
plt.ylabel(r"Predicted energy values with" 
           "\n" r"aleatoric uncertainty",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.tight_layout()
#plt.axline([0, 0], [1, 1])
plt.savefig('val-ale-uq.png')

# %%
plt.figure(figsize=(8,4))
plt.errorbar(preprocessor_output.inverse_transform(s_vy).flatten(),
             preprocessor_output.inverse_transform(pred_ty_mean).flatten(), 
             epistemic_error.flatten(),
             fmt='o', color='black',
             ecolor='gray', elinewidth=2, capsize=0)
             #linestyle='None', marker='^')
plt.plot(preprocessor_output.inverse_transform(s_vy).flatten(),preprocessor_output.inverse_transform(s_vy).flatten())
plt.xlabel("Observed energy values", fontsize=15)
plt.ylabel(r"Predicted energy values with" 
           "\n" r"epistemic uncertainty",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.tight_layout()
#plt.axline([0, 0], [1, 1])
plt.savefig('val-epi-uq.png')

# %%
from matplotlib import pyplot

bins = np.arange(0.0,3.0,0.1)

plt.figure(figsize=(8,4))
pyplot.hist(aleatoric_error, bins, alpha=0.5, label='Aleatoric')
pyplot.hist(epistemic_error, bins, alpha=0.5, label='Epistemic')
pyplot.legend(loc='upper right',prop={'size': 15})
pyplot.xlabel("Uncertainty", fontsize=15)
pyplot.ylabel("Frequency",fontsize=15)
pyplot.xticks(fontsize=14)
pyplot.yticks(fontsize=14)
pyplot.grid()
pyplot.tight_layout()
pyplot.savefig('val-hist-uq.png')
